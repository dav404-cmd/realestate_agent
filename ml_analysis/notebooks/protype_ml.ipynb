# %% [markdown]
# ## Data exploring

# %%
import sys
import os
import pandas as pd
# Add the project root (the folder containing both ml_analysis and manage_db)
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(project_root)

from manage_db.db_manager import DbManager

# %%
pd.set_option("display.max_columns", None)

# %%
db = DbManager(table_name="jp_realestate",source=None)
df = db.load_data()
df
# Out:
# C:\Users\nox map\PycharmProjects\realestate_agent\manage_db\db_manager.py:114: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors="ignore")
# key     id         source                 scraped_at available_from  \
# 0      284  realestate.co 2025-12-03 10:18:30.580965     2025-07-25
# 1      285  realestate.co 2025-12-03 10:18:30.580965            NaN
# 2      286  realestate.co 2025-12-03 10:18:30.580965     2025-10-15
# 3      287  realestate.co 2025-12-03 10:18:30.580965            NaN
# 4      288  realestate.co 2025-12-03 10:18:30.580965     2025-11-25
# ...    ...            ...                        ...            ...
# 4497  5583  realestate.co 2025-12-12 10:15:46.818907            NaN
# 4498  5584  realestate.co 2025-12-12 10:15:46.818907            NaN
# 4499  5585  realestate.co 2025-12-12 10:15:46.818907     2025-12-12
# 4500  5586  realestate.co 2025-12-12 10:15:46.818907     2025-12-12
# 4501  5587  realestate.co 2025-12-12 10:15:46.818907            NaN
#
# key   balcony_size  building_area_ratio  \
# 0             2.40                  NaN
# 1             8.64                  NaN
# 2              NaN                 40.0
# 3             8.29                  NaN
# 4              NaN                 40.0
# ...            ...                  ...
# 4497          5.00                  NaN
# 4498          8.90                  NaN
# 4499          6.32                  NaN
# 4500          8.20                  NaN
# 4501           NaN                  NaN
#
# key                                building_description  \
# 0     ◆About This Area◆ Hiroo Station, located in To...
# 1     Baycrest Tower is a tower apartment with a tot...
# 2     Enjoy breathtaking views of Sagami Bay, Mount ...
# 3     ◆ Introduction to Azabu Ichibeicho Homes ◆ “Az...
# 4     ★Renovated 7 bedrooms (including a Japanese-st...
# ...                                                 ...
# 4497                                                NaN
# 4498                                                NaN
# 4499                                                NaN
# 4500                                                NaN
# 4501  A rare detached house in Miyamae-ku, Kawasaki ...
#
# key               building_name  construction_completed date_updated  \
# 0      Ryowa Palace Nishi-Azabu                  1999.0   2025-10-29
# 1               BAY CREST TOWER                     NaN   2025-11-18
# 2                        横須賀市秋谷                  1974.0   2025-10-20
# 3        Azabu Ichibeicho Homes                  2004.0   2025-11-27
# 4                         鎌倉市 津                  1987.0   2025-11-26
# ...                         ...                     ...          ...
# 4497                 ユニ・アルス真田山南                  1998.0   2025-12-12
# 4498                 ガーデンコート河原町                  1999.0   2025-12-12
# 4499               ライオンズマンション門真                  1983.0   2025-12-12
# 4500              池上パークファミリア2号棟                  1979.0   2025-12-12
# 4501  Miyamae-ku, Kawasaki City                  1977.0   2025-12-10
#
# key         direction_facing     floor  floor_area_ratio  floors  gross_yield  \
# 0     North, Northeast, East    [2, 8]               NaN     NaN          NaN
# 1                      South  [23, 40]               NaN     NaN          NaN
# 2                      South       NaN              80.0     2.0          NaN
# 3                  Southwest   [8, 15]               NaN     NaN          NaN
# 4                      South       NaN              80.0     2.0          NaN
# ...                      ...       ...               ...     ...          ...
# 4497               Southwest    [8, 8]               NaN     NaN         4.52
# 4498                   South   [3, 11]               NaN     NaN         3.81
# 4499                   South   [6, 11]               NaN     NaN         7.18
# 4500                   South   [6, 11]               NaN     NaN         5.63
# 4501                    West       NaN               NaN     2.0        18.00
#
# key  investment_situation  land_area land_rights  \
# 0                     NaN        NaN    Freehold
# 1                     NaN    6102.72    Freehold
# 2                     NaN     938.24    Freehold
# 3                     NaN        NaN    Freehold
# 4                     NaN     441.22    Freehold
# ...                   ...        ...         ...
# 4497         Fully rented     297.85    Freehold
# 4498         Fully rented    1182.89    Freehold
# 4499         Fully rented        NaN    Freehold
# 4500                  NaN        NaN    Freehold
# 4501                  NaN      78.00    Freehold
#
# key                                           landmarks layout  \
# 0     ・Tourist Spot: Chokokuji Temple (Approx. 6-min...   1LDK
# 1                                                   NaN   2LDK
# 2                                                   NaN   3LDK
# 3     🇺🇸 American English Azabu Municipal Nursery Sc...   2LDK
# 4                                                   NaN   7LDK
# ...                                                 ...    ...
# 4497  Convenience store (208m), Supermarket (243m), ...   2LDK
# 4498  Convenience store (323m), Convenience store (3...  2SLDK
# 4499  Supermarket (553m), Supermarket (536m), Superm...   3LDK
# 4500                                                NaN    3DK
# 4501                                                NaN   3LDK
#
# key                                    location  maintenance_fee  \
# 0                  Nishiazabu, Minato-ku, Tokyo          12250.0
# 1                       Konan, Minato-ku, Tokyo          13100.0
# 2                 Akiya, Yokosuka-shi, Kanagawa              NaN
# 3                    Roppongi, Minato-ku, Tokyo          23900.0
# 4                   Tsu, Kamakura-shi, Kanagawa              NaN
# ...                                         ...              ...
# 4497    Ajiharacho, Osaka-shi Tennoji-ku, Osaka          14800.0
# 4498  Yorozuyacho, Kyoto-shi Shimogyo-ku, Kyoto          13700.0
# 4499                Shojicho, Kadoma-shi, Osaka           7690.0
# 4500                 Nakaikegami, Ota-ku, Tokyo          14000.0
# 4501   Sugao, Kawasaki-shi Miyamae-ku, Kanagawa              NaN
#
# key                       manage_type  \
# 0         Fully Outsourced Management
# 1                                 NaN
# 2                                 NaN
# 3     Partially Outsourced Management
# 4                                 NaN
# ...                               ...
# 4497      Fully Outsourced Management
# 4498      Fully Outsourced Management
# 4499      Fully Outsourced Management
# 4500      Fully Outsourced Management
# 4501                              NaN
#
# key                                 manager_style  \
# 0     Day Shift Management (Commuting Management)
# 1                                             NaN
# 2                                             NaN
# 3     Day Shift Management (Commuting Management)
# 4                                             NaN
# ...                                           ...
# 4497  Day Shift Management (Commuting Management)
# 4498  Day Shift Management (Commuting Management)
# 4499  Day Shift Management (Commuting Management)
# 4500  Day Shift Management (Commuting Management)
# 4501                                          NaN
#
# key                                     nearest_station next_update_schedule  \
# 0     Hiroo Station (8 min. walk) Tokyo Metro Hibiya...           2026-01-27
# 1       Tennozu Isle Station (12 min. walk) Rinkai Line           2025-12-18
# 2       Zushi Station (17 min. by bus) JR Yokosuka Line           2026-01-18
# 3     Kamiyacho Station (8 min. walk) Tokyo Metro Hi...           2026-02-25
# 4     Kamakura Koukoumae Station (10 min. walk) Enos...           2026-02-24
# ...                                                 ...                  ...
# 4497   Tsuruhashi Station (5 min. walk) Ōsaka Loop Line           2026-01-11
# 4498    Shichijo Station (6 min. walk) Keihan Main Line           2026-01-11
# 4499  Kadoma Shi Station (6 min. walk) Keihan Main Line           2026-01-11
# 4500  Nishimagome Station (9 min. walk) Toei Asakusa...           2026-01-11
# 4501                                                NaN           2026-01-09
#
# key  occupancy        other_expenses                   parking  \
# 0       Vacant                  5000  Available, ¥55,000 / mth
# 1     Occupied  Internet Service Fee  Available, ¥30,000 / mth
# 2     Occupied                     -                 Available
# 3       Vacant                   NaN  Available, ¥40,000 / mth
# 4       Vacant                     -                 Available
# ...        ...                   ...                       ...
# 4497  Occupied                 24495                       NaN
# 4498  Occupied                 19020                       NaN
# 4499    Vacant                  8760                       NaN
# 4500    Vacant                  8000                       NaN
# 4501    Vacant                   NaN                       NaN
#
# key   potential_annual_rent  price_yen repair_reserve_fund  road_width  \
# 0                       NaN   69990000       ¥13,410 / mth         NaN
# 1                       NaN  114800000       ¥16,600 / mth         NaN
# 2                       NaN  155000000                 NaN         NaN
# 3                       NaN  368000000       ¥17,920 / mth         NaN
# 4                       NaN  129000000                 NaN         NaN
# ...                     ...        ...                 ...         ...
# 4497              1440000.0   31800000       ¥24,495 / mth         NaN
# 4498              1596000.0   41800000       ¥19,020 / mth         NaN
# 4499               920040.0   12800000        ¥8,760 / mth         NaN
# 4500              1680000.0   29800000        ¥8,000 / mth         NaN
# 4501              1260000.0    7000000                 NaN         NaN
#
# key  sell_situation    size                  structure transaction_type  \
# 0               NaN   38.66  Steel Reinforced Concrete    Non-Exclusive
# 1          Occupied   62.42        Reinforced Concrete        Brokerage
# 2               NaN  119.84                       Wood    Non-Exclusive
# 3               NaN   69.99        Reinforced Concrete        Brokerage
# 4               NaN  273.41          Light Gauge Steel    Non-Exclusive
# ...             ...     ...                        ...              ...
# 4497         Rented   64.44        Reinforced Concrete           Seller
# 4498         Rented   75.45  Steel Reinforced Concrete           Seller
# 4499         Rented   59.59  Steel Reinforced Concrete           Seller
# 4500         Rented   61.60  Steel Reinforced Concrete           Seller
# 4501            NaN   57.00                       Wood           Seller
#
# key      type unit_number unit_summary  \
# 0     Mansion         202          NaN
# 1     Mansion         23F          NaN
# 2       House         NaN          NaN
# 3     Mansion         NaN          NaN
# 4       House         NaN          NaN
# ...       ...         ...          ...
# 4497  Mansion         802          NaN
# 4498  Mansion         306          NaN
# 4499  Mansion         606          NaN
# 4500  Mansion         611          NaN
# 4501    House         NaN          NaN
#
# key                                                url  year_built  \
# 0     https://realestate.co.jp/en/forsale/view/1256872         NaN
# 1     https://realestate.co.jp/en/forsale/view/1287626      2005.0
# 2     https://realestate.co.jp/en/forsale/view/1285660         NaN
# 3     https://realestate.co.jp/en/forsale/view/1287498         NaN
# 4     https://realestate.co.jp/en/forsale/view/1299053         NaN
# ...                                                ...         ...
# 4497  https://realestate.co.jp/en/forsale/view/1271602         NaN
# 4498  https://realestate.co.jp/en/forsale/view/1271599         NaN
# 4499  https://realestate.co.jp/en/forsale/view/1250675         NaN
# 4500  https://realestate.co.jp/en/forsale/view/1250602         NaN
# 4501  https://realestate.co.jp/en/forsale/view/1274085         NaN
#
# key                     zoning
# 0                  Residential
# 1                   Industrial
# 2                  Residential
# 3                          NaN
# 4                  Residential
# ...                        ...
# 4497                Commercial
# 4498                Commercial
# 4499  Residential / Commercial
# 4500                Industrial
# 4501                       NaN
#
# [4502 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4502 entries, 0 to 4501
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      4502 non-null   int64
#  1   source                  4502 non-null   object
#  2   scraped_at              4502 non-null   datetime64[ns]
#  3   available_from          1994 non-null   object
#  4   balcony_size            1989 non-null   float64
#  5   building_area_ratio     1350 non-null   float64
#  6   building_description    4074 non-null   object
#  7   building_name           4491 non-null   object
#  8   construction_completed  3096 non-null   float64
#  9   date_updated            4502 non-null   object
#  10  direction_facing        3989 non-null   object
#  11  floor                   3035 non-null   object
#  12  floor_area_ratio        1388 non-null   float64
#  13  floors                  1200 non-null   float64
#  14  gross_yield             378 non-null    float64
#  15  investment_situation    25 non-null     object
#  16  land_area               1744 non-null   float64
#  17  land_rights             4499 non-null   object
#  18  landmarks               2003 non-null   object
#  19  layout                  4468 non-null   object
#  20  location                4502 non-null   object
#  21  maintenance_fee         3016 non-null   float64
#  22  manage_type             2230 non-null   object
#  23  manager_style           1918 non-null   object
#  24  nearest_station         4292 non-null   object
#  25  next_update_schedule    4502 non-null   object
#  26  occupancy               4444 non-null   object
#  27  other_expenses          2840 non-null   object
#  28  parking                 2119 non-null   object
#  29  potential_annual_rent   386 non-null    float64
#  30  price_yen               4502 non-null   int64
#  31  repair_reserve_fund     2759 non-null   object
#  32  road_width              529 non-null    float64
#  33  sell_situation          317 non-null    object
#  34  size                    4468 non-null   float64
#  35  structure               4381 non-null   object
#  36  transaction_type        4502 non-null   object
#  37  type                    4468 non-null   object
#  38  unit_number             2463 non-null   object
#  39  unit_summary            257 non-null    object
#  40  url                     4502 non-null   object
#  41  year_built              1372 non-null   float64
#  42  zoning                  3843 non-null   object
# dtypes: datetime64[ns](1), float64(12), int64(2), object(28)
# memory usage: 1.5+ MB

# %%
df.type.value_counts()
# Out:
# type
# Mansion          3034
# House            1223
# Hotel/Ryokan      134
# Retail             25
# Apartment          17
# Holiday House      15
# Office             11
# Terrace house       4
# Town house          3
# Other               2
# Name: count, dtype: int64

# %%
df.manage_type.value_counts()
# Out:
# manage_type
# Fully Outsourced Management        2142
# Partially Outsourced Management      46
# Self-Management                      42
# Name: count, dtype: int64

# %%
df.occupancy.value_counts()
# Out:
# occupancy
# Vacant      3412
# Occupied    1032
# Name: count, dtype: int64

# %%
df.gross_yield.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4502 entries, 0 to 4501
# Series name: gross_yield
# Non-Null Count  Dtype
# --------------  -----
# 378 non-null    float64
# dtypes: float64(1)
# memory usage: 35.3 KB

# %%
df.location.value_counts()    #needs forther data division into (city,distric....)
# Out:
# location
# Akasaka, Minato-ku, Tokyo                             57
# Mita, Minato-ku, Tokyo                                56
# Shirokane, Minato-ku, Tokyo                           55
# Minamiaoyama, Minato-ku, Tokyo                        55
# Yoyogi, Shibuya-ku, Tokyo                             50
#                                                       ..
# Zuibaiji, Itoshima-shi, Fukuoka                        1
# Takatsuji inokumacho, Kyoto-shi Shimogyo-ku, Kyoto     1
# Nishibatacho, Nagoya-shi Showa-ku, Aichi               1
# Bishamoncho, Kyoto-shi Shimogyo-ku, Kyoto              1
# Tsu, Kamakura-shi, Kanagawa                            1
# Name: count, Length: 1695, dtype: int64

# %%
df.structure.unique()
# Out:
# array(['Steel Reinforced Concrete', 'Reinforced Concrete', 'Wood',
#        'Light Gauge Steel', nan, 'Steel Frame',
#        'Precast Reinforced Concrete', 'Other', 'Concrete Block'],
#       dtype=object)

# %% [markdown]
# ## data preprocessing

# %%
import ast

import re

def parse_floor_safe(x):
    if not isinstance(x, str):
        return None
    
    # extract all integers
    nums = re.findall(r'\d+', x)
    if not nums:
        return None
    
    return list(map(int, nums))
 
df["floor_clean"] = df["floor"].apply(parse_floor_safe)


df["building_total_floors"] = df["floor_clean"].apply(lambda x: x[0] if x else None)
df["unit_floor"] = df["floor_clean"].apply(lambda x: x[1] if x else None)

df["building_total_floors"] = df["building_total_floors"].fillna(df["floors"])

# for houses (entire house), unit_floor is usually treated as 1
df.loc[df["unit_floor"].isna() & df["floors"].notna(), "unit_floor"] = 1

# %%
df = df.drop(columns=["floor","floors","floor_clean","id","source","scraped_at","building_description","building_name","date_updated","gross_yield","unit_number","unit_summary","url","next_update_schedule","landmarks","manager_style","manage_type","other_expenses"])

# %%
def clean_parking(df):
    df["clean_parking"] = (
        df["parking"]
        .fillna("")                               # replace NaN with empty string
        .astype(str)                              # ensure all values are strings
    )
    df["parking_status"] = (
        df['clean_parking']
        .str.split(",").str[0].str.strip()        # extract first part
        .eq("Available")                          # compare to "Available"
        .astype(int)                              # convert True/False → 1/0
    )
    
    df["parking_cost_mth"] = (
        df["clean_parking"]
        .str.extract(r"¥([\d,]+)\s*/\s*mth")[0]
        .str.replace(",", "")
        .astype(float)
    )
    

    df = df.drop(columns=["clean_parking","parking"])
    df["parking_cost_mth"] = df["parking_cost_mth"].fillna(0)
    return df

df = clean_parking(df)
df[['parking_status','parking_cost_mth']]
# Out:
# key   parking_status  parking_cost_mth
# 0                  1           55000.0
# 1                  1           30000.0
# 2                  1               0.0
# 3                  1           40000.0
# 4                  1               0.0
# ...              ...               ...
# 4497               0               0.0
# 4498               0               0.0
# 4499               0               0.0
# 4500               0               0.0
# 4501               0               0.0
#
# [4502 rows x 2 columns]

# %%
df["built_year"] = df["construction_completed"].fillna(df["year_built"])
df= df.drop(columns=["construction_completed","year_built"])

# %%
df.location
# Out:
# 0                    Nishiazabu, Minato-ku, Tokyo
# 1                         Konan, Minato-ku, Tokyo
# 2                   Akiya, Yokosuka-shi, Kanagawa
# 3                      Roppongi, Minato-ku, Tokyo
# 4                     Tsu, Kamakura-shi, Kanagawa
#                           ...
# 4497      Ajiharacho, Osaka-shi Tennoji-ku, Osaka
# 4498    Yorozuyacho, Kyoto-shi Shimogyo-ku, Kyoto
# 4499                  Shojicho, Kadoma-shi, Osaka
# 4500                   Nakaikegami, Ota-ku, Tokyo
# 4501     Sugao, Kawasaki-shi Miyamae-ku, Kanagawa
# Name: location, Length: 4502, dtype: object

# %%
def split_location(df):
    df["location"] = df["location"].fillna("")
    parts = df["location"].str.split(",", expand=True)
    
    df["prefecture"] = parts[2].str.strip()
    return df.drop(columns=["location"])

df = split_location(df)

# %%
df = df.join(pd.get_dummies(df["prefecture"],prefix="prefecture").astype(int)).drop("prefecture",axis=1)

# %%
df = df.join(pd.get_dummies(df["land_rights"],prefix="land_rights").astype(int)).drop("land_rights",axis=1)
df = df.join(pd.get_dummies(df["occupancy"],prefix="occ").astype(int)).drop("occupancy",axis=1)
df = df.join(pd.get_dummies(df["structure"],prefix="structure").astype(int)).drop("structure",axis=1)
df = df.join(pd.get_dummies(df["zoning"],prefix="zoning").astype(int)).drop("zoning",axis=1)
df = df.join(pd.get_dummies(df["transaction_type"],prefix="transaction").astype(int)).drop("transaction_type",axis=1)
df = df.join(pd.get_dummies(df["type"],prefix="type").astype(int)).drop("type",axis=1)

# %%
df.layout.unique()
# Out:
# array(['1LDK', '2LDK', '3LDK', '7LDK', '6K', 'Whole Building', '5LDK',
#        '4LDK', '5SLDK', '2SLDK', '1R', '2DK', '6SLDK', '3SLDK', '10LDK',
#        '4SLDK', '1K', '3DK', '4DK', '4K', '6DK', '8DK', '9SLDK', '1SLDK',
#        '1DK', '6LDK', '7K', '5K', '8LDK', '1SDK', '7SLDK', '9LDK',
#        '8SLDK', '5DK', '10SLDK', '6SDK', '2K', '10K', '3K', nan, 'Shop',
#        'Office', '7DK', '4SLK', '2SDK', '9DK', '10DK', '8K', '5SDK',
#        '3SLK', '2SLK', '1SK', '5SK', '4SDK', '2SK', '9K'], dtype=object)

# %%
import re
import numpy as np

def clean_layout(df):
    # standardize to string
    df["layout"] = df["layout"].fillna("").astype(str).str.strip()

    # 1. Flag whole-building listings
    df["is_whole_building"] = df["layout"].str.contains("whole", case=False).astype(int)

    # 2. Extract number of rooms (LDK style)
    # e.g. 1LDK, 3DK, 2K → extract leading digits
    df["rooms"] = df["layout"].str.extract(r"^(\d+)").astype(float)

    # 3. Detect layout characters (L, D, K)
    df["has_living"] = df["layout"].str.contains("L", case=False).astype(int)
    df["has_dining"] = df["layout"].str.contains("D", case=False).astype(int)
    df["has_kitchen"] = df["layout"].str.contains("K", case=False).astype(int)
    df["has_storage"] = df["layout"].str.contains(r"S(?!TUDIO)", case=False).astype(int)

    # 4. Studio / R-type detection (1R, R, SR)
    r_pattern = r"(^1R$)|(^R$)|(^SR$)|(\b1R\b)|(\bR\b)"
    is_r_type = df["layout"].str.contains(r_pattern, case=False)


    # 5. Fill missing rooms for whole buildings with NaN (can't infer)
    df.loc[df["is_whole_building"] == 1, "rooms"] = np.nan

    df = df.drop(columns = ["layout"])

    return df

# %%
df = clean_layout(df)
# Out:
# C:\Users\nox map\AppData\Local\Temp\ipykernel_8396\2178700966.py:23: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   is_r_type = df["layout"].str.contains(r_pattern, case=False)

# %%
df[["is_whole_building","rooms","has_living","has_dining","has_kitchen","has_storage"]]
# Out:
#       is_whole_building  rooms  has_living  has_dining  has_kitchen  \
# 0                     0    1.0           1           1            1
# 1                     0    2.0           1           1            1
# 2                     0    3.0           1           1            1
# 3                     0    2.0           1           1            1
# 4                     0    7.0           1           1            1
# ...                 ...    ...         ...         ...          ...
# 4497                  0    2.0           1           1            1
# 4498                  0    2.0           1           1            1
# 4499                  0    3.0           1           1            1
# 4500                  0    3.0           0           1            1
# 4501                  0    3.0           1           1            1
#
#       has_storage
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 4497            0
# 4498            1
# 4499            0
# 4500            0
# 4501            0
#
# [4502 rows x 6 columns]

# %%
valid_dirs = {
    "NORTH", "SOUTH", "EAST", "WEST",
    "NORTHEAST", "NORTHWEST",
    "SOUTHEAST", "SOUTHWEST"
}
def clean_direction(d):
    if pd.isna(d):
        return []
    parts = [p.strip().upper() for p in d.split(",")]
    return [p for p in parts if p in valid_dirs]

df['direction_list'] = df['direction_facing'].apply(clean_direction)

for d in valid_dirs:
    df[f"dir_{d}"] = df["direction_list"].apply(lambda lst: int(d in lst))

# %%
df = df.drop(columns=["direction_facing","direction_list"])

# %%
df = df.drop(columns=["sell_situation","road_width"])

# %%
df.repair_reserve_fund.unique()
# Out:
# array(['¥13,410 / mth', '¥16,600 / mth', nan, ..., '¥23,910 / mth',
#        '¥8,360 / mth', '¥24,495 / mth'], shape=(1609,), dtype=object)

# %%
df["repair_reserve_fund"] = (
    df["repair_reserve_fund"]
    .fillna("")
    .astype(str)
    .str.replace(r"\D", "", regex=True)
    .replace("", None)  # replace empty strings with None
    .pipe(pd.to_numeric, errors="coerce")
)

# %%
df.floor_area_ratio.isna().value_counts()
# Out:
# floor_area_ratio
# True     3114
# False    1388
# Name: count, dtype: int64

# %%
df.building_area_ratio.isna().value_counts()
# Out:
# building_area_ratio
# True     3152
# False    1350
# Name: count, dtype: int64

# %%
df.balcony_size.isna().value_counts()
# Out:
# balcony_size
# True     2513
# False    1989
# Name: count, dtype: int64

# %%
df.land_area.isna().value_counts()
# Out:
# land_area
# True     2758
# False    1744
# Name: count, dtype: int64

# %%
df.potential_annual_rent.isna().value_counts()
# Out:
# potential_annual_rent
# True     4116
# False     386
# Name: count, dtype: int64

# %%
df.available_from.isna().value_counts()
# Out:
# available_from
# True     2508
# False    1994
# Name: count, dtype: int64

# %%
df = df.drop(columns=["floor_area_ratio","building_area_ratio","balcony_size","land_area","potential_annual_rent"])

# %%
df['built_year'] = df['built_year'].astype('Int64')

# %%
df.built_year
# Out:
# 0       1999
# 1       2005
# 2       1974
# 3       2004
# 4       1987
#         ...
# 4497    1998
# 4498    1999
# 4499    1983
# 4500    1979
# 4501    1977
# Name: built_year, Length: 4502, dtype: Int64

# %%
from datetime import datetime

current_year = datetime.now().year

df['building_age'] = current_year - df['built_year']

# %%
df.available_from
# Out:
# 0       2025-07-25
# 1              NaN
# 2       2025-10-15
# 3              NaN
# 4       2025-11-25
#            ...
# 4497           NaN
# 4498           NaN
# 4499    2025-12-12
# 4500    2025-12-12
# 4501           NaN
# Name: available_from, Length: 4502, dtype: object

# %%
# Convert to datetime
df['available_from'] = pd.to_datetime(df['available_from'], errors='coerce')

# Create a missing flag
df['available_from_missing'] = df['available_from'].isna().astype(int)

# Days until available (NaN stays if missing)
df['days_until_available'] = (df['available_from'] - pd.Timestamp.today()).dt.days

# Extract month and year for seasonality patterns
df['available_month'] = df['available_from'].dt.month
df['available_year'] = df['available_from'].dt.year

# %%
df[["available_from","available_from_missing","days_until_available","available_month","available_year"]]
# Out:
#      available_from  available_from_missing  days_until_available  \
# 0        2025-07-25                       0                -143.0
# 1               NaT                       1                   NaN
# 2        2025-10-15                       0                 -61.0
# 3               NaT                       1                   NaN
# 4        2025-11-25                       0                 -20.0
# ...             ...                     ...                   ...
# 4497            NaT                       1                   NaN
# 4498            NaT                       1                   NaN
# 4499     2025-12-12                       0                  -3.0
# 4500     2025-12-12                       0                  -3.0
# 4501            NaT                       1                   NaN
#
#       available_month  available_year
# 0                 7.0          2025.0
# 1                 NaN             NaN
# 2                10.0          2025.0
# 3                 NaN             NaN
# 4                11.0          2025.0
# ...               ...             ...
# 4497              NaN             NaN
# 4498              NaN             NaN
# 4499             12.0          2025.0
# 4500             12.0          2025.0
# 4501              NaN             NaN
#
# [4502 rows x 5 columns]

# %%
df['nearest_station'].unique()
# Out:
# array(['Hiroo Station (8 min. walk) Tokyo Metro Hibiya Line',
#        'Tennozu Isle Station (12 min. walk) Rinkai Line',
#        'Zushi Station (17 min. by bus) JR Yokosuka Line', ...,
#        'Shichijo Station (6 min. walk) Keihan Main Line',
#        'Kadoma Shi Station (6 min. walk) Keihan Main Line',
#        'Nishimagome Station (9 min. walk) Toei Asakusa Line'],
#       shape=(2835,), dtype=object)

# %%
import re

def parse_station(s):
    if pd.isna(s):
        return pd.Series([None, None, None, None])
    
    # Regex to capture: Station name, minutes, mode, line
    match = re.match(r"^(.*?) Station \((\d+) min\. (.*?)\) (.*)$", s)
    if match:
        station_name = match.group(1).strip()
        minutes = int(match.group(2))
        mode = match.group(3).strip()
        line = match.group(4).strip()
        return pd.Series([station_name, minutes, mode, line])
    else:
        return pd.Series([s, None, None, None])  # fallback

df[['ns_station_name','ns_minutes','ns_mode','ns_line']] = df['nearest_station'].apply(parse_station)

# %%
df[['ns_station_name','ns_minutes','ns_mode','ns_line']]
# Out:
#          ns_station_name  ns_minutes ns_mode                    ns_line
# 0                  Hiroo         8.0    walk    Tokyo Metro Hibiya Line
# 1           Tennozu Isle        12.0    walk                Rinkai Line
# 2                  Zushi        17.0  by bus           JR Yokosuka Line
# 3              Kamiyacho         8.0    walk    Tokyo Metro Hibiya Line
# 4     Kamakura Koukoumae        10.0    walk  Enoshima Electric Railway
# ...                  ...         ...     ...                        ...
# 4497          Tsuruhashi         5.0    walk            Ōsaka Loop Line
# 4498            Shichijo         6.0    walk           Keihan Main Line
# 4499          Kadoma Shi         6.0    walk           Keihan Main Line
# 4500         Nishimagome         9.0    walk          Toei Asakusa Line
# 4501                None         NaN    None                       None
#
# [4502 rows x 4 columns]

# %%
df.ns_station_name.nunique()
# Out:
# 1117

# %%
df.ns_line.nunique()
# Out:
# 259

# %%
# Top 10 stations
top10_stations = df['ns_station_name'].value_counts().nlargest(10).index
df['ns_station_name_reduced'] = df['ns_station_name'].where(df['ns_station_name'].isin(top10_stations), 'Other')

# Top 10 lines
top10_lines = df['ns_line'].value_counts().nlargest(10).index
df['ns_line_reduced'] = df['ns_line'].where(df['ns_line'].isin(top10_lines), 'Other')

# %%
df[['ns_station_name_reduced','ns_line_reduced']]
# Out:
#      ns_station_name_reduced          ns_line_reduced
# 0                      Hiroo  Tokyo Metro Hibiya Line
# 1                      Other                    Other
# 2                      Other                    Other
# 3                      Other  Tokyo Metro Hibiya Line
# 4                      Other                    Other
# ...                      ...                      ...
# 4497                   Other                    Other
# 4498                   Other                    Other
# 4499                   Other                    Other
# 4500                   Other                    Other
# 4501                   Other                    Other
#
# [4502 rows x 2 columns]

# %%
df = df.join(pd.get_dummies(df["ns_station_name_reduced"],prefix="station").astype(int)).drop("ns_station_name_reduced",axis=1)
df = df.join(pd.get_dummies(df["ns_line_reduced"],prefix="line").astype(int)).drop("ns_line_reduced",axis=1)

# %%
df = df.drop(columns=["nearest_station"])

# %%
df = df.drop(columns=['ns_station_name','ns_minutes','ns_mode','ns_line'])

# %%
df = df.drop(columns=["available_from"])

# %%
df = df.drop(columns=["investment_situation"])

# %%
df.columns = df.columns.str.replace(" ","_")

# %% [markdown]
# # Ml

# %%
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from lightgbm import LGBMRegressor, early_stopping, log_evaluation
import shap
import matplotlib.pyplot as plt
import seaborn as sns

# %%
TARGET = "price_yen"
RANDOM_STATE = 42
TEST_SIZE = 0.2

# %%
y = df[TARGET].values
X = df.drop(columns=[TARGET])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %%
# Train model (LightGBM)
model = LGBMRegressor(
    n_estimators=2000,
    learning_rate=0.05,
    num_leaves=31,
    max_depth=-1,
    random_state=RANDOM_STATE,
    n_jobs=-1,
)

# Early stopping using validation set
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric="rmse",
    callbacks=[early_stopping(100), log_evaluation(100)]
)


# 7) Evaluate
def eval_preds(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    return {
        "mae": mae,
        "rmse": rmse,
        "r2": r2
    }

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

train_metrics = eval_preds(y_train, y_train_pred)
test_metrics = eval_preds(y_test, y_test_pred)

print("TRAIN metrics:", train_metrics)
print("TEST metrics :", test_metrics)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001613 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1431
# [LightGBM] [Info] Number of data points in the train set: 3601, number of used features: 87
# [LightGBM] [Info] Start training from score 144913711.251319
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's rmse: 9.91766e+07	valid_0's l2: 9.836e+15
# [200]	valid_0's rmse: 9.75682e+07	valid_0's l2: 9.51955e+15
# [300]	valid_0's rmse: 9.97205e+07	valid_0's l2: 9.94418e+15
# Early stopping, best iteration is:
# [211]	valid_0's rmse: 9.74289e+07	valid_0's l2: 9.49239e+15
# TRAIN metrics: {'mae': 34028083.238792285, 'rmse': np.float64(94910164.01309754), 'r2': 0.8455647576597386}
# TEST metrics : {'mae': 47375133.92882294, 'rmse': np.float64(97428876.35738392), 'r2': 0.7179954439889474}

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train)

shap.summary_plot(shap_values, X_train)

# %%
from pathlib import Path

cwd = Path.cwd()   # current working directory
root = cwd.parents[1].resolve()
model_dir = root / "ml_analysis" / "models"
print(f"root : {root} , model_dir : {model_dir}")
# Out:
# root : C:\Users\nox map\PycharmProjects\realestate_agent , model_dir : C:\Users\nox map\PycharmProjects\realestate_agent\ml_analysis\model

# %%
import joblib
# Create the directory if it doesn't exist
model_dir.mkdir(parents=True, exist_ok=True)
file_path = model_dir / "lgbm_price_model.pkl"
joblib.dump(model, file_path)
print(f"Saved model -> {file_path}")
# Out:
# Saved model -> C:\Users\nox map\PycharmProjects\realestate_agent\ml_analysis\model\lgbm_price_model.pkl
