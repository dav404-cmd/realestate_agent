# %% [markdown]
# ## Data exploring

# %%
import sys
import os
import pandas as pd
# Add the project root (the folder containing both ml_analysis and manage_db)
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(project_root)

from manage_db.db_manager import DbManager

# %%
pd.set_option("display.max_columns", None)

# %%
db = DbManager(table_name="jp_realestate",source=None)
df = db.load_data()
df.head(10)
# Out:
# C:\Users\nox map\PycharmProjects\realestate_agent\manage_db\db_manager.py:114: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors="ignore")
# key   id         source                 scraped_at available_from  \
# 0    236  realestate.co 2025-12-02 13:08:21.771013     2025-10-15
# 1    237  realestate.co 2025-12-02 13:08:21.771013            NaN
# 2    238  realestate.co 2025-12-02 13:08:21.771013     2025-11-05
# 3    239  realestate.co 2025-12-02 13:08:21.771013            NaN
# 4    240  realestate.co 2025-12-02 13:08:21.771013     2025-11-25
# 5    241  realestate.co 2025-12-02 13:08:21.771013     2025-10-15
# 6    242  realestate.co 2025-12-02 13:08:21.771013     2025-07-25
# 7    243  realestate.co 2025-12-02 13:08:21.771013     2025-10-25
# 8    244  realestate.co 2025-12-02 13:08:21.771013            NaN
# 9    245  realestate.co 2025-12-02 13:08:21.771013     2025-11-01
#
# key  balcony_size  building_area_ratio  \
# 0             NaN                 60.0
# 1           12.00                  NaN
# 2             NaN                 50.0
# 3            8.29                  NaN
# 4             NaN                 40.0
# 5             NaN                 40.0
# 6            2.40                  NaN
# 7             NaN                 60.0
# 8           31.02                  NaN
# 9             NaN                 80.0
#
# key                               building_description  \
# 0    The high-ceilinged dining room, hollow stairca...
# 1                                                  NaN
# 2    A luxury villa area near the Niseko Higashiyam...
# 3    ◆ Introduction to Azabu Ichibeicho Homes ◆ “Az...
# 4    ★Renovated 7 bedrooms (including a Japanese-st...
# 5    Enjoy breathtaking views of Sagami Bay, Mount ...
# 6    ◆About This Area◆ Hiroo Station, located in To...
# 7    Stunning oceanfront residence owner's living q...
# 8    ◆ Tokyu Livable-owned property ☆No brokerage fee☆
# 9    Conveniently located near a train station. Acc...
#
# key              building_name  construction_completed date_updated  \
# 0                    天王寺阪南町6丁目                  2017.0   2025-10-15
# 1                   トルナーレ日本橋浜町                  2005.0   2025-12-02
# 2                       ニセコヴィラ                  2019.0   2025-11-10
# 3       Azabu Ichibeicho Homes                  2004.0   2025-11-27
# 4                        鎌倉市 津                  1987.0   2025-11-26
# 5                       横須賀市秋谷                  1974.0   2025-10-20
# 6     Ryowa Palace Nishi-Azabu                  1999.0   2025-10-29
# 7                  うるま市石川東恩納民泊                  2019.0   2025-10-24
# 8    Crescent MITAKA The Tower                  2007.0   2025-11-22
# 9                         百合の宿                  1975.0   2025-11-05
#
# key        direction_facing     floor  floor_area_ratio     floors  \
# 0              North, South       NaN             200.0  [3, null]
# 1                 Southeast  [29, 46]               NaN        NaN
# 2                     North       NaN             200.0  [2, null]
# 3                 Southwest   [8, 15]               NaN        NaN
# 4                     South       NaN              80.0  [2, null]
# 5                     South       NaN              80.0  [2, null]
# 6    North, Northeast, East    [2, 8]               NaN        NaN
# 7                 Southwest       NaN             200.0        NaN
# 8                 Southeast  [21, 21]               NaN        NaN
# 9          Southeast, South    [2, 4]             400.0        NaN
#
# key  gross_yield  land_area land_rights  \
# 0            NaN     100.89    Freehold
# 1            NaN        NaN    Freehold
# 2            NaN     593.00    Freehold
# 3            NaN        NaN    Freehold
# 4            NaN     441.22    Freehold
# 5            NaN     938.24    Freehold
# 6            NaN        NaN    Freehold
# 7            NaN     389.57    Freehold
# 8            NaN        NaN    Freehold
# 9            NaN      45.50    Freehold
#
# key                                          landmarks          layout  \
# 0                                                    -            4LDK
# 1                                                  NaN           2SLDK
# 2                                                  NaN            3LDK
# 3    🇺🇸 American English Azabu Municipal Nursery Sc...            2LDK
# 4                                                  NaN            7LDK
# 5                                                  NaN            3LDK
# 6    ・Tourist Spot: Chokokuji Temple (Approx. 6-min...            1LDK
# 7                                                  NaN  Whole Building
# 8                                                  NaN            2LDK
# 9                                                  NaN            2LDK
#
# key                                     location  maintenance_fee  \
# 0           Hannancho, Osaka-shi Abeno-ku, Osaka              NaN
# 1              Nihombashihamacho, Chuo-ku, Tokyo          22590.0
# 2    Higashiyama, Abuta-gun Niseko-cho, Hokkaido              NaN
# 3                     Roppongi, Minato-ku, Tokyo          23900.0
# 4                    Tsu, Kamakura-shi, Kanagawa              NaN
# 5                  Akiya, Yokosuka-shi, Kanagawa              NaN
# 6                   Nishiazabu, Minato-ku, Tokyo          12250.0
# 7       Ishikawa higashionna, Uruma-shi, Okinawa              NaN
# 8                Shimorenjaku, Mitaka-shi, Tokyo          31900.0
# 9         Kokubucho, Osaka-shi Tennoji-ku, Osaka              NaN
#
# key                      manage_type  \
# 0                                NaN
# 1        Fully Outsourced Management
# 2                                NaN
# 3    Partially Outsourced Management
# 4                                NaN
# 5                                NaN
# 6        Fully Outsourced Management
# 7                                NaN
# 8        Fully Outsourced Management
# 9                                NaN
#
# key                                manager_style  \
# 0                                            NaN
# 1    Day Shift Management (Commuting Management)
# 2                                            NaN
# 3    Day Shift Management (Commuting Management)
# 4                                            NaN
# 5                                            NaN
# 6    Day Shift Management (Commuting Management)
# 7                                            NaN
# 8    Day Shift Management (Commuting Management)
# 9                                            NaN
#
# key                                    nearest_station next_update_schedule  \
# 0    Nishitanabe Station (4 min. walk) Osaka Metro ...           2026-01-13
# 1    Suitengumae Station (5 min. walk) Tokyo Metro ...           2026-03-02
# 2    Niseko Station (10 min. by car) JR Hakodate Ma...           2026-02-08
# 3    Kamiyacho Station (8 min. walk) Tokyo Metro Hi...           2026-02-25
# 4    Kamakura Koukoumae Station (10 min. walk) Enos...           2026-02-24
# 5      Zushi Station (17 min. by bus) JR Yokosuka Line           2026-01-18
# 6    Hiroo Station (8 min. walk) Tokyo Metro Hibiya...           2026-01-27
# 7           Nahakukou Station (30+ min. walk) Yui Rail           2026-01-22
# 8    Mitaka Station (2 min. walk) JR Chūō Line (Rapid)           2026-02-20
# 9     Teradachou Station (6 min. walk) Ōsaka Loop Line           2026-02-03
#
# key occupancy other_expenses                   parking  potential_annual_rent  \
# 0      Vacant              -                 Available                    NaN
# 1      Vacant            NaN                       NaN                    NaN
# 2      Vacant              -                 Available                    NaN
# 3      Vacant            NaN  Available, ¥40,000 / mth                    NaN
# 4      Vacant              -                 Available                    NaN
# 5    Occupied              -                 Available                    NaN
# 6      Vacant           5000  Available, ¥55,000 / mth                    NaN
# 7    Occupied              -                 Available                    NaN
# 8      Vacant            897                       NaN                    NaN
# 9      Vacant              -                       NaN                    NaN
#
# key  price_yen repair_reserve_fund  road_width sell_situation    size  \
# 0     99800000                 NaN         NaN            NaN  153.93
# 1    265000000       ¥26,420 / mth         NaN          Empty   90.90
# 2    260000000                 NaN         NaN            NaN  183.89
# 3    368000000       ¥17,920 / mth         NaN            NaN   69.99
# 4    129000000                 NaN         NaN            NaN  273.41
# 5    155000000                 NaN         NaN            NaN  119.84
# 6     69990000       ¥13,410 / mth         NaN            NaN   38.66
# 7    298000000                 NaN         NaN            NaN  389.57
# 8    176800000       ¥16,900 / mth         NaN            NaN   84.69
# 9    120000000                 NaN         NaN            NaN  118.22
#
# key                  structure transaction_type          type unit_number  \
# 0                         Wood    Non-Exclusive         House         NaN
# 1    Steel Reinforced Concrete           Seller       Mansion           -
# 2          Reinforced Concrete    Non-Exclusive         House         NaN
# 3          Reinforced Concrete        Brokerage       Mansion         NaN
# 4            Light Gauge Steel    Non-Exclusive         House         NaN
# 5                         Wood    Non-Exclusive         House         NaN
# 6    Steel Reinforced Concrete    Non-Exclusive       Mansion         202
# 7          Reinforced Concrete    Non-Exclusive  Hotel/Ryokan         NaN
# 8          Reinforced Concrete           Seller       Mansion         NaN
# 9                  Steel Frame    Non-Exclusive  Hotel/Ryokan         NaN
#
# key unit_summary                                               url  \
# 0            NaN  https://realestate.co.jp/en/forsale/view/1283352
# 1            NaN  https://realestate.co.jp/en/forsale/view/1232916
# 2            NaN  https://realestate.co.jp/en/forsale/view/1293165
# 3            NaN  https://realestate.co.jp/en/forsale/view/1287498
# 4            NaN  https://realestate.co.jp/en/forsale/view/1299053
# 5            NaN  https://realestate.co.jp/en/forsale/view/1285660
# 6            NaN  https://realestate.co.jp/en/forsale/view/1256872
# 7            NaN  https://realestate.co.jp/en/forsale/view/1286810
# 8            NaN  https://realestate.co.jp/en/forsale/view/1235045
# 9            NaN  https://realestate.co.jp/en/forsale/view/1291242
#
# key  year_built       zoning
# 0           NaN  Residential
# 1           NaN   Commercial
# 2           NaN  Residential
# 3           NaN          NaN
# 4           NaN  Residential
# 5           NaN  Residential
# 6           NaN  Residential
# 7           NaN  Residential
# 8           NaN   Commercial
# 9           NaN  Residential

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      47 non-null     int64
#  1   source                  47 non-null     object
#  2   scraped_at              47 non-null     datetime64[ns]
#  3   available_from          31 non-null     object
#  4   balcony_size            18 non-null     float64
#  5   building_area_ratio     18 non-null     float64
#  6   building_description    46 non-null     object
#  7   building_name           47 non-null     object
#  8   construction_completed  35 non-null     float64
#  9   date_updated            47 non-null     object
#  10  direction_facing        46 non-null     object
#  11  floor                   30 non-null     object
#  12  floor_area_ratio        18 non-null     float64
#  13  floors                  16 non-null     object
#  14  gross_yield             2 non-null      float64
#  15  land_area               24 non-null     float64
#  16  land_rights             47 non-null     object
#  17  landmarks               10 non-null     object
#  18  layout                  47 non-null     object
#  19  location                47 non-null     object
#  20  maintenance_fee         27 non-null     float64
#  21  manage_type             18 non-null     object
#  22  manager_style           15 non-null     object
#  23  nearest_station         43 non-null     object
#  24  next_update_schedule    47 non-null     object
#  25  occupancy               47 non-null     object
#  26  other_expenses          32 non-null     object
#  27  parking                 25 non-null     object
#  28  potential_annual_rent   2 non-null      float64
#  29  price_yen               47 non-null     int64
#  30  repair_reserve_fund     22 non-null     object
#  31  road_width              6 non-null      float64
#  32  sell_situation          2 non-null      object
#  33  size                    47 non-null     float64
#  34  structure               46 non-null     object
#  35  transaction_type        47 non-null     object
#  36  type                    47 non-null     object
#  37  unit_number             17 non-null     object
#  38  unit_summary            1 non-null      object
#  39  url                     47 non-null     object
#  40  year_built              12 non-null     float64
#  41  zoning                  44 non-null     object
# dtypes: datetime64[ns](1), float64(11), int64(2), object(28)
# memory usage: 15.6+ KB

# %%
df.manage_type.value_counts()
# Out:
# manage_type
# Fully Outsourced Management        16
# Partially Outsourced Management     2
# Name: count, dtype: int64

# %%
df.occupancy.value_counts()
# Out:
# occupancy
# Vacant      37
# Occupied    10
# Name: count, dtype: int64

# %%
df.location.value_counts()    #needs forther data division into (city,distric....)
# Out:
# location
# Hannancho, Osaka-shi Abeno-ku, Osaka                     2
# Higashiikebukuro, Toshima-ku, Tokyo                      2
# Nihombashihamacho, Chuo-ku, Tokyo                        1
# Roppongi, Minato-ku, Tokyo                               1
# Higashiyama, Abuta-gun Niseko-cho, Hokkaido              1
# Akiya, Yokosuka-shi, Kanagawa                            1
# Nishiazabu, Minato-ku, Tokyo                             1
# Ishikawa higashionna, Uruma-shi, Okinawa                 1
# Shimorenjaku, Mitaka-shi, Tokyo                          1
# Kokubucho, Osaka-shi Tennoji-ku, Osaka                   1
# Kamakurayama, Kamakura-shi, Kanagawa                     1
# Hase, Kamakura-shi, Kanagawa                             1
# Tsu, Kamakura-shi, Kanagawa                              1
# Kichijoji honcho, Musashino-shi, Tokyo                   1
# Takatsuji inokumacho, Kyoto-shi Shimogyo-ku, Kyoto       1
# Bishamoncho, Kyoto-shi Shimogyo-ku, Kyoto                1
# Nishibatacho, Nagoya-shi Showa-ku, Aichi                 1
# Toranomon, Minato-ku, Tokyo                              1
# Hiroo, Shibuya-ku, Tokyo                                 1
# Sugamo, Toshima-ku, Tokyo                                1
# Kyuden, Setagaya-ku, Tokyo                               1
# Shinsencho, Shibuya-ku, Tokyo                            1
# Toyosaki, Osaka-shi Kita-ku, Osaka                       1
# Ebisu, Shibuya-ku, Tokyo                                 1
# Funabashi, Setagaya-ku, Tokyo                            1
# Asahidori, Kobe-shi Chuo-ku, Hyogo                       1
# Tomihisacho, Shinjuku-ku, Tokyo                          1
# Shima nogita, Itoshima-shi, Fukuoka                      1
# Daimachi, Yokohama-shi Kanagawa-ku, Kanagawa             1
# Shirokane, Minato-ku, Tokyo                              1
# Sengokuhara, Ashigarashimo-gun Hakone-machi, Kanagawa    1
# Miyota, Kitasaku-gun Miyota-machi, Nagano                1
# Minato, Chuo-ku, Tokyo                                   1
# Hatagaya, Shibuya-ku, Tokyo                              1
# Konan, Minato-ku, Tokyo                                  1
# Yakuin, Fukuoka-shi Chuo-ku, Fukuoka                     1
# Daita, Setagaya-ku, Tokyo                                1
# Izumigaoka, Izumisano-shi, Osaka                         1
# Ashiharacho, Nishinomiya-shi, Hyogo                      1
# Eifuku, Suginami-ku, Tokyo                               1
# Akatsutsumi, Setagaya-ku, Tokyo                          1
# Takanawa, Minato-ku, Tokyo                               1
# Itabashi, Itabashi-ku, Tokyo                             1
# Katsura inuicho, Kyoto-shi Nishikyo-ku, Kyoto            1
# Ueno miyaguni, Miyakojima-shi, Okinawa                   1
# Name: count, dtype: int64

# %% [markdown]
# ## data preprocessing
