# %% [markdown]
# ## Data exploring

# %%
import sys
import os
import pandas as pd
# Add the project root (the folder containing both ml_analysis and manage_db)
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(project_root)

from manage_db.db_manager import DbManager

# %%
pd.set_option("display.max_columns", None)

# %%
db = DbManager(table_name="jp_realestate",source=None)
df = db.load_data()
df
# Out:
# C:\Users\nox map\PycharmProjects\realestate_agent\manage_db\db_manager.py:114: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors="ignore")
# key   id         source                 scraped_at available_from  \
# 0    284  realestate.co 2025-12-03 10:18:30.580965     2025-07-25
# 1    285  realestate.co 2025-12-03 10:18:30.580965            NaN
# 2    286  realestate.co 2025-12-03 10:18:30.580965     2025-10-15
# 3    287  realestate.co 2025-12-03 10:18:30.580965            NaN
# 4    288  realestate.co 2025-12-03 10:18:30.580965     2025-11-25
# ..   ...            ...                        ...            ...
# 462  775  realestate.co 2025-12-03 10:40:31.719475     2025-05-15
# 463  776  realestate.co 2025-12-03 10:40:31.719475     2025-10-15
# 464  777  realestate.co 2025-12-03 10:40:31.719475     2025-09-05
# 465  778  realestate.co 2025-12-03 10:40:31.719475     2025-10-25
# 466  779  realestate.co 2025-12-03 10:40:31.719475     2025-07-05
#
# key  balcony_size  building_area_ratio  \
# 0            2.40                  NaN
# 1            8.64                  NaN
# 2             NaN                 40.0
# 3            8.29                  NaN
# 4             NaN                 40.0
# ..            ...                  ...
# 462           NaN                 80.0
# 463           NaN                 90.0
# 464           NaN                 80.0
# 465           NaN                 50.0
# 466           NaN                 80.0
#
# key                               building_description  \
# 0    ◆About This Area◆ Hiroo Station, located in To...
# 1    Baycrest Tower is a tower apartment with a tot...
# 2    Enjoy breathtaking views of Sagami Bay, Mount ...
# 3    ◆ Introduction to Azabu Ichibeicho Homes ◆ “Az...
# 4    ★Renovated 7 bedrooms (including a Japanese-st...
# ..                                                 ...
# 462  "SORA is an investment consulting company that...
# 463  Current annual sales are approximately 25 mill...
# 464  Private accommodations. The interior is stylis...
# 465  In addition to the lofty living and dining roo...
# 466  "SORA is an investment consulting company that...
#
# key             building_name  construction_completed date_updated  \
# 0    Ryowa Palace Nishi-Azabu                  1999.0   2025-10-29
# 1             BAY CREST TOWER                     NaN   2025-11-18
# 2                      横須賀市秋谷                  1974.0   2025-10-20
# 3      Azabu Ichibeicho Homes                  2004.0   2025-11-27
# 4                       鎌倉市 津                  1987.0   2025-11-26
# ..                        ...                     ...          ...
# 462                      鶴橋 里                  1996.0   2025-11-12
# 463                     ホテル免許                  2019.0   2025-10-16
# 464              南区北烏丸町ゲストハウス                  2019.0   2025-11-04
# 465               豊見城市豊崎 3LDK                  2024.0   2025-10-24
# 466                    大阪市鶴見区                  2024.0   2025-11-04
#
# key        direction_facing     floor  floor_area_ratio  floors  gross_yield  \
# 0    North, Northeast, East    [2, 8]               NaN     NaN          NaN
# 1                     South  [23, 40]               NaN     NaN          NaN
# 2                     South       NaN              80.0     2.0          NaN
# 3                 Southwest   [8, 15]               NaN     NaN          NaN
# 4                     South       NaN              80.0     2.0          NaN
# ..                      ...       ...               ...     ...          ...
# 462                   South       NaN             400.0     3.0        10.03
# 463                   South    [3, 3]             300.0     NaN          NaN
# 464             South, West       NaN             400.0     NaN         6.28
# 465        Southeast, South       NaN             100.0     2.0          NaN
# 466                    East       NaN             160.0     2.0          NaN
#
# key  land_area land_rights                                          landmarks  \
# 0          NaN    Freehold  ・Tourist Spot: Chokokuji Temple (Approx. 6-min...
# 1      6102.72    Freehold                                                NaN
# 2       938.24    Freehold                                                NaN
# 3          NaN    Freehold  🇺🇸 American English Azabu Municipal Nursery Sc...
# 4       441.22    Freehold                                                NaN
# ..         ...         ...                                                ...
# 462      85.78    Freehold                                                NaN
# 463     113.81    Freehold                                                NaN
# 464      60.06    Freehold                                                NaN
# 465     192.88    Freehold                                                NaN
# 466     231.40    Freehold                                                NaN
#
# key          layout                                           location  \
# 0              1LDK                       Nishiazabu, Minato-ku, Tokyo
# 1              2LDK                            Konan, Minato-ku, Tokyo
# 2              3LDK                      Akiya, Yokosuka-shi, Kanagawa
# 3              2LDK                         Roppongi, Minato-ku, Tokyo
# 4              7LDK                        Tsu, Kamakura-shi, Kanagawa
# ..              ...                                                ...
# 462  Whole Building              Tsuruhashi, Osaka-shi Ikuno-ku, Osaka
# 463            9LDK    Oimazatominami, Osaka-shi Higashinari-ku, Osaka
# 464  Whole Building  Higashikujo kitakarasumacho, Kyoto-shi Minami-...
# 465            3LDK                  Toyosaki, Tomigusuku-shi, Okinawa
# 466            3LDK               Tsurumi, Osaka-shi Tsurumi-ku, Osaka
#
# key  maintenance_fee                      manage_type  \
# 0            12250.0      Fully Outsourced Management
# 1            13100.0                              NaN
# 2                NaN                              NaN
# 3            23900.0  Partially Outsourced Management
# 4                NaN                              NaN
# ..               ...                              ...
# 462              NaN                              NaN
# 463              NaN                              NaN
# 464              NaN                              NaN
# 465              NaN                              NaN
# 466              NaN                              NaN
#
# key                                manager_style  \
# 0    Day Shift Management (Commuting Management)
# 1                                            NaN
# 2                                            NaN
# 3    Day Shift Management (Commuting Management)
# 4                                            NaN
# ..                                           ...
# 462                                          NaN
# 463                                          NaN
# 464                                          NaN
# 465                                          NaN
# 466                                          NaN
#
# key                                    nearest_station next_update_schedule  \
# 0    Hiroo Station (8 min. walk) Tokyo Metro Hibiya...           2026-01-27
# 1      Tennozu Isle Station (12 min. walk) Rinkai Line           2025-12-18
# 2      Zushi Station (17 min. by bus) JR Yokosuka Line           2026-01-18
# 3    Kamiyacho Station (8 min. walk) Tokyo Metro Hi...           2026-02-25
# 4    Kamakura Koukoumae Station (10 min. walk) Enos...           2026-02-24
# ..                                                 ...                  ...
# 462  Tsuruhashi Station (2 min. walk) Kintetsu Ōsak...           2026-02-10
# 463  Imasato Station Osaka Metro Subway Imazatosuji...           2026-01-14
# 464  Kujo Station (3 min. walk) Kyoto City Subway K...           2026-02-02
# 465           Akamine Station (30+ min. walk) Yui Rail           2026-01-22
# 466  Imafuku Tsurumi Station (8 min. walk) Osaka Me...           2026-02-02
#
# key occupancy        other_expenses                   parking  \
# 0      Vacant                  5000  Available, ¥55,000 / mth
# 1    Occupied  Internet Service Fee  Available, ¥30,000 / mth
# 2    Occupied                     -                 Available
# 3      Vacant                   NaN  Available, ¥40,000 / mth
# 4      Vacant                     -                 Available
# ..        ...                   ...                       ...
# 462    Vacant                     -                       NaN
# 463  Occupied                     -                       NaN
# 464    Vacant                     -                       NaN
# 465    Vacant                     -                 Available
# 466    Vacant                     -                 Available
#
# key  potential_annual_rent  price_yen repair_reserve_fund  road_width  \
# 0                      NaN   69990000       ¥13,410 / mth         NaN
# 1                      NaN  114800000       ¥16,600 / mth         NaN
# 2                      NaN  155000000                 NaN         NaN
# 3                      NaN  368000000       ¥17,920 / mth         NaN
# 4                      NaN  129000000                 NaN         NaN
# ..                     ...        ...                 ...         ...
# 462              9783336.0   97500000                 NaN         NaN
# 463                    NaN  165000000                 NaN         NaN
# 464             13255380.0  211000000                 NaN         NaN
# 465                    NaN  118000000                 NaN         NaN
# 466                    NaN   64800000                 NaN         4.0
#
# key sell_situation    size                  structure transaction_type  \
# 0              NaN   38.66  Steel Reinforced Concrete    Non-Exclusive
# 1         Occupied   62.42        Reinforced Concrete        Brokerage
# 2              NaN  119.84                       Wood    Non-Exclusive
# 3              NaN   69.99        Reinforced Concrete        Brokerage
# 4              NaN  273.41          Light Gauge Steel    Non-Exclusive
# ..             ...     ...                        ...              ...
# 462            NaN  177.22                Steel Frame    Non-Exclusive
# 463            NaN  229.43                       Wood    Non-Exclusive
# 464            NaN  125.26                Steel Frame    Non-Exclusive
# 465            NaN  123.17                       Wood    Non-Exclusive
# 466            NaN  105.30                       Wood    Non-Exclusive
#
# key          type unit_number unit_summary  \
# 0         Mansion         202          NaN
# 1         Mansion         23F          NaN
# 2           House         NaN          NaN
# 3         Mansion         NaN          NaN
# 4           House         NaN          NaN
# ..            ...         ...          ...
# 462  Hotel/Ryokan         NaN          NaN
# 463  Hotel/Ryokan         NaN          NaN
# 464  Hotel/Ryokan         NaN          NaN
# 465         House         NaN          NaN
# 466         House         NaN          NaN
#
# key                                               url  year_built       zoning
# 0    https://realestate.co.jp/en/forsale/view/1256872         NaN  Residential
# 1    https://realestate.co.jp/en/forsale/view/1287626      2005.0   Industrial
# 2    https://realestate.co.jp/en/forsale/view/1285660         NaN  Residential
# 3    https://realestate.co.jp/en/forsale/view/1287498         NaN          NaN
# 4    https://realestate.co.jp/en/forsale/view/1299053         NaN  Residential
# ..                                                ...         ...          ...
# 462  https://realestate.co.jp/en/forsale/view/1230792         NaN   Commercial
# 463  https://realestate.co.jp/en/forsale/view/1283667         NaN  Residential
# 464  https://realestate.co.jp/en/forsale/view/1273718         NaN   Commercial
# 465  https://realestate.co.jp/en/forsale/view/1286939         NaN  Residential
# 466  https://realestate.co.jp/en/forsale/view/1248228         NaN  Residential
#
# [467 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      467 non-null    int64
#  1   source                  467 non-null    object
#  2   scraped_at              467 non-null    datetime64[ns]
#  3   available_from          163 non-null    object
#  4   balcony_size            211 non-null    float64
#  5   building_area_ratio     149 non-null    float64
#  6   building_description    458 non-null    object
#  7   building_name           467 non-null    object
#  8   construction_completed  381 non-null    float64
#  9   date_updated            467 non-null    object
#  10  direction_facing        413 non-null    object
#  11  floor                   305 non-null    object
#  12  floor_area_ratio        149 non-null    float64
#  13  floors                  131 non-null    float64
#  14  gross_yield             36 non-null     float64
#  15  land_area               173 non-null    float64
#  16  land_rights             467 non-null    object
#  17  landmarks               302 non-null    object
#  18  layout                  467 non-null    object
#  19  location                467 non-null    object
#  20  maintenance_fee         293 non-null    float64
#  21  manage_type             238 non-null    object
#  22  manager_style           231 non-null    object
#  23  nearest_station         434 non-null    object
#  24  next_update_schedule    467 non-null    object
#  25  occupancy               464 non-null    object
#  26  other_expenses          298 non-null    object
#  27  parking                 258 non-null    object
#  28  potential_annual_rent   33 non-null     float64
#  29  price_yen               467 non-null    int64
#  30  repair_reserve_fund     283 non-null    object
#  31  road_width              69 non-null     float64
#  32  sell_situation          5 non-null      object
#  33  size                    467 non-null    float64
#  34  structure               462 non-null    object
#  35  transaction_type        467 non-null    object
#  36  type                    467 non-null    object
#  37  unit_number             142 non-null    object
#  38  unit_summary            6 non-null      object
#  39  url                     467 non-null    object
#  40  year_built              86 non-null     float64
#  41  zoning                  312 non-null    object
# dtypes: datetime64[ns](1), float64(12), int64(2), object(27)
# memory usage: 153.4+ KB

# %%
df.type.value_counts()
# Out:
# type
# Mansion          301
# House            133
# Hotel/Ryokan      27
# Holiday House      2
# Apartment          2
# Office             1
# Retail             1
# Name: count, dtype: int64

# %%
df.manage_type.value_counts()
# Out:
# manage_type
# Fully Outsourced Management        232
# Partially Outsourced Management      5
# Self-Management                      1
# Name: count, dtype: int64

# %%
df.occupancy.value_counts()
# Out:
# occupancy
# Vacant      352
# Occupied    112
# Name: count, dtype: int64

# %%
df.gross_yield.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 467 entries, 0 to 466
# Series name: gross_yield
# Non-Null Count  Dtype
# --------------  -----
# 36 non-null     float64
# dtypes: float64(1)
# memory usage: 3.8 KB

# %%
df.location.value_counts()    #needs forther data division into (city,distric....)
# Out:
# location
# Shirokane, Minato-ku, Tokyo               14
# Mita, Minato-ku, Tokyo                    13
# Akasaka, Minato-ku, Tokyo                 10
# Nishiazabu, Minato-ku, Tokyo               8
# Kamiuma, Setagaya-ku, Tokyo                8
#                                           ..
# Funabashi, Setagaya-ku, Tokyo              1
# Kokubucho, Osaka-shi Tennoji-ku, Osaka     1
# Suitocho, Suita-shi, Osaka                 1
# Toyama(sonota), Shinjuku-ku, Tokyo         1
# Shinsencho, Shibuya-ku, Tokyo              1
# Name: count, Length: 294, dtype: int64

# %%
df.structure.unique()
# Out:
# array(['Steel Reinforced Concrete', 'Reinforced Concrete', 'Wood',
#        'Light Gauge Steel', nan, 'Steel Frame',
#        'Precast Reinforced Concrete'], dtype=object)

# %% [markdown]
# ## data preprocessing

# %%
import ast

def parse_range(x):
    if isinstance(x, str) and x.startswith("[") and x.endswith("]"):
        return ast.literal_eval(x)
    return None  
df["floor_clean"] = df["floor"].apply(parse_range)


df["building_total_floors"] = df["floor_clean"].apply(lambda x: x[0] if x else None)
df["unit_floor"] = df["floor_clean"].apply(lambda x: x[1] if x else None)

df["building_total_floors"] = df["building_total_floors"].fillna(df["floors"])

# for houses (entire house), unit_floor is usually treated as 1
df.loc[df["unit_floor"].isna() & df["floors"].notna(), "unit_floor"] = 1

# %%
df = df.drop(columns=["floor","floors","floor_clean","id","source","scraped_at","building_description","building_name","date_updated","gross_yield","unit_number","unit_summary","url","next_update_schedule","landmarks","manager_style","manage_type","other_expenses"])

# %%
def clean_parking(df):
    df["clean_parking"] = (
        df["parking"]
        .fillna("")                               # replace NaN with empty string
        .astype(str)                              # ensure all values are strings
    )
    df["parking_status"] = (
        df['clean_parking']
        .str.split(",").str[0].str.strip()        # extract first part
        .eq("Available")                          # compare to "Available"
        .astype(int)                              # convert True/False → 1/0
    )
    
    df["parking_cost_mth"] = (
        df["clean_parking"]
        .str.extract(r"¥([\d,]+)\s*/\s*mth")[0]
        .str.replace(",", "")
        .astype(float)
    )
    

    df = df.drop(columns=["clean_parking","parking"])
    df["parking_cost_mth"] = df["parking_cost_mth"].fillna(0)
    return df

df = clean_parking(df)
df[['parking_status','parking_cost_mth']]
# Out:
# key  parking_status  parking_cost_mth
# 0                 1           55000.0
# 1                 1           30000.0
# 2                 1               0.0
# 3                 1           40000.0
# 4                 1               0.0
# ..              ...               ...
# 462               0               0.0
# 463               0               0.0
# 464               0               0.0
# 465               1               0.0
# 466               1               0.0
#
# [467 rows x 2 columns]

# %%
df["built_year"] = df["construction_completed"].fillna(df["year_built"])
df= df.drop(columns=["construction_completed","year_built"])

# %%
df.built_year
# Out:
# 0      1999.0
# 1      2005.0
# 2      1974.0
# 3      2004.0
# 4      1987.0
#         ...
# 462    1996.0
# 463    2019.0
# 464    2019.0
# 465    2024.0
# 466    2024.0
# Name: built_year, Length: 467, dtype: float64

# %%
df.other_expenses
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9324\815868246.py in ?()
# ----> 1 df.other_expenses
#
# ~\PycharmProjects\realestate_agent\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'other_expenses'
